# %%
import matplotlib.pyplot as plt
from meerkat import test_device, parser

# %%
td = test_device.TestDevice(writer_output='json')

# %%
plt.plot(td._deg, td._amp);

# %%
td.verbose = False
td.verbose_data = False

# %%
td.go = True
td.run()

# %%
td.json_writer.path
# Out:
# '2020_11_02_17_26_32_Software Test_dummy_data.jsontxt'

# %%
with open(td.json_writer.path, 'r') as f:
    for n in range(12):
        print(f.readline())
# Out:
# {"std_time_ms": "2020-11-02 17:26:32.138636", "description": 0, "sample_n": 0, "degree": 0.0}
#
# {"std_time_ms": "2020-11-02 17:26:32.138867", "description": 1, "sample_n": 1, "degree": 0.01745240643728351}
#
# {"std_time_ms": "2020-11-02 17:26:32.138965", "description": 2, "sample_n": 2, "degree": 0.03489949670250097}
#
# {"std_time_ms": "2020-11-02 17:26:32.139045", "description": 3, "sample_n": 3, "degree": 0.052335956242943835}
#
# {"std_time_ms": "2020-11-02 17:26:32.139122", "description": 4, "sample_n": 4, "degree": 0.0697564737441253}
#
# {"std_time_ms": "2020-11-02 17:26:32.139196", "description": 5, "sample_n": 5, "degree": 0.08715574274765817}
#
# {"std_time_ms": "2020-11-02 17:26:32.139285", "description": 6, "sample_n": 6, "degree": 0.10452846326765347}
#
# {"std_time_ms": "2020-11-02 17:26:32.139373", "description": 7, "sample_n": 7, "degree": 0.12186934340514748}
#
# {"std_time_ms": "2020-11-02 17:26:32.139482", "description": 8, "sample_n": 8, "degree": 0.13917310096006544}
#
# {"std_time_ms": "2020-11-02 17:26:32.139569", "description": 9, "sample_n": 9, "degree": 0.15643446504023087, "name": "Software Test", "encoding": "utf-8", "format": "text/json", "standard": "RFC 8259", "line_terminator": "\n", "quote_char": "\"", "double_quote": true, "escape_char": "\\", "null_sequence": "NA", "comment": "#", "path": "2020_11_02_17_26_32_Software Test_dummy_data.jsontxt", "metadata": {"name": "Software Test", "description": "dummy_data", "urls": "www.example.com", "manufacturer": "Nikola Tesla Company", "header": ["std_time_ms", "description", "sample_n", "degree", "amplitude"], "dtype": ["datetime", "str", "int", "float", "float"], "units": ["time", null, "count", "degrees", "real numbers"], "accuracy": [null, null, 1, 0.2, 0.2], "precision": [null, null, 1, 0.1, 0.1], "time_format": "std_time_ms", "strfmtime": "%Y-%m-%d %H:%M:%S.%f"}, "metadata_interval": 10}
#
# {"std_time_ms": "2020-11-02 17:26:32.139760", "description": 10, "sample_n": 10, "degree": 0.17364817766693033}
#
# {"std_time_ms": "2020-11-02 17:26:32.139846", "description": 11, "sample_n": 11, "degree": 0.1908089953765448}

# %%
td.writer_output = 'csv'

# %%
td.go = True
td.run()

# %%
td.csv_writer.path
# Out:
# '2020_11_02_17_26_32_Software Test_dummy_data.csv'

# %%
m, df = parser.csv_resource(td.csv_writer.path)

# %%
m
# Out:
# {'name': 'Software Test',
#  'description': 'dummy_data',
#  'encoding': 'utf-8',
#  'format': 'text/csv',
#  'standard': 'Follow RFC 4180',
#  'line_terminator': '\n',
#  'quote_char': '"',
#  'double_quote': True,
#  'escape_char': '\\',
#  'null_sequence': 'NA',
#  'comment': '#',
#  'path': '2020_11_02_17_26_32_Software Test_dummy_data.csv',
#  'metadata': {'name': 'Software Test',
#   'description': 'dummy_data',
#   'urls': 'www.example.com',
#   'manufacturer': 'Nikola Tesla Company',
#   'header': ['std_time_ms', 'description', 'sample_n', 'degree', 'amplitude'],
#   'dtype': ['datetime', 'str', 'int', 'float', 'float'],
#   'units': ['time', None, 'count', 'degrees', 'real numbers'],
#   'accuracy': [None, None, 1, 0.2, 0.2],
#   'precision': [None, None, 1, 0.1, 0.1],
#   'time_format': 'std_time_ms',
#   'strfmtime': '%Y-%m-%d %H:%M:%S.%f'},
#  'delimiter': ',',
#  'skip_initial_space': True,
#  'case_sensitive_header': False,
#  'skip_lines': 1}

# %%
df
# Out:
#                     std_time_ms description  sample_n  degree  amplitude  \
# 0    2020-11-02 17:26:32.262805  dummy_data         0       0   0.000000
# 1    2020-11-02 17:26:32.262890  dummy_data         1       1   0.017452
# 2    2020-11-02 17:26:32.262971  dummy_data         2       2   0.034899
# 3    2020-11-02 17:26:32.263079  dummy_data         3       3   0.052336
# 4    2020-11-02 17:26:32.263175  dummy_data         4       4   0.069756
# ..                          ...         ...       ...     ...        ...
# 995  2020-11-02 17:26:32.344054  dummy_data       995     275  -0.996195
# 996  2020-11-02 17:26:32.344111  dummy_data       996     276  -0.994522
# 997  2020-11-02 17:26:32.344167  dummy_data       997     277  -0.992546
# 998  2020-11-02 17:26:32.344222  dummy_data       998     278  -0.990268
# 999  2020-11-02 17:26:32.344277  dummy_data       999     279  -0.987688
#
#                  datetime64_ns
# 0   2020-11-02 17:26:32.262805
# 1   2020-11-02 17:26:32.262890
# 2   2020-11-02 17:26:32.262971
# 3   2020-11-02 17:26:32.263079
# 4   2020-11-02 17:26:32.263175
# ..                         ...
# 995 2020-11-02 17:26:32.344054
# 996 2020-11-02 17:26:32.344111
# 997 2020-11-02 17:26:32.344167
# 998 2020-11-02 17:26:32.344222
# 999 2020-11-02 17:26:32.344277
#
# [1000 rows x 6 columns]

# %%
df[["std_time_ms", "degree", "amplitude"]].plot(x='std_time_ms',
                                                secondary_y="amplitude",
                                                figsize=(10,8), rot=45);

# %%
df.loc[0:359, ["degree", "amplitude"]].plot(x='degree', figsize=(10,8));

# %%
df.head()
# Out:
#                   std_time_ms description  sample_n  degree  amplitude  \
# 0  2020-11-02 17:26:32.262805  dummy_data         0       0   0.000000
# 1  2020-11-02 17:26:32.262890  dummy_data         1       1   0.017452
# 2  2020-11-02 17:26:32.262971  dummy_data         2       2   0.034899
# 3  2020-11-02 17:26:32.263079  dummy_data         3       3   0.052336
# 4  2020-11-02 17:26:32.263175  dummy_data         4       4   0.069756
#
#                datetime64_ns
# 0 2020-11-02 17:26:32.262805
# 1 2020-11-02 17:26:32.262890
# 2 2020-11-02 17:26:32.262971
# 3 2020-11-02 17:26:32.263079
# 4 2020-11-02 17:26:32.263175

# %%
df.tail()
# Out:
#                     std_time_ms description  sample_n  degree  amplitude  \
# 995  2020-11-02 17:26:32.344054  dummy_data       995     275  -0.996195
# 996  2020-11-02 17:26:32.344111  dummy_data       996     276  -0.994522
# 997  2020-11-02 17:26:32.344167  dummy_data       997     277  -0.992546
# 998  2020-11-02 17:26:32.344222  dummy_data       998     278  -0.990268
# 999  2020-11-02 17:26:32.344277  dummy_data       999     279  -0.987688
#
#                  datetime64_ns
# 995 2020-11-02 17:26:32.344054
# 996 2020-11-02 17:26:32.344111
# 997 2020-11-02 17:26:32.344167
# 998 2020-11-02 17:26:32.344222
# 999 2020-11-02 17:26:32.344277
