# %%
import matplotlib.pyplot as plt
from meerkat import test_device

# %%
td = test_device.TestDevice(output='json')

# %%
plt.plot(td._deg, td._amp);

# %%
td.verbose = True
td.verbose_data = True

# %%
td.go = True
td.run()
# Out:
# Test Started
# {"data": [0, 0, 0.0], "std_time": "2018-12-27 16:15:47"}
# {"data": [1, 1, 0.01745240643728351], "std_time": "2018-12-27 16:15:47"}
# {"data": [2, 2, 0.03489949670250097], "std_time": "2018-12-27 16:15:47"}
# {"data": [3, 3, 0.052335956242943835], "std_time": "2018-12-27 16:15:47"}
# {"data": [4, 4, 0.0697564737441253], "std_time": "2018-12-27 16:15:47"}
# {"data": [5, 5, 0.08715574274765817], "std_time": "2018-12-27 16:15:47"}
# {"data": [6, 6, 0.10452846326765347], "std_time": "2018-12-27 16:15:47"}
# {"data": [7, 7, 0.12186934340514748], "std_time": "2018-12-27 16:15:47"}
# {"data": [8, 8, 0.13917310096006544], "std_time": "2018-12-27 16:15:47"}
# {"data": [9, 9, 0.15643446504023087], "std_time": "2018-12-27 16:15:47"}
# {"data": [10, 10, 0.17364817766693033], "std_time": "2018-12-27 16:15:47"}
# {"data": [11, 11, 0.1908089953765448], "std_time": "2018-12-27 16:15:47"}
# {"data": [12, 12, 0.20791169081775934], "std_time": "2018-12-27 16:15:47"}
# ...
