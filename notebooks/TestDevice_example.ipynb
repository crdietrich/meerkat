# %%
import matplotlib.pyplot as plt
from meerkat import test_device, parser

# %%
td = test_device.TestDevice(bus_n=1, bus_addr=0x00, output='json')

# %%
plt.plot(td._deg, td._amp);

# %%
td.verbose = False
td.verbose_data = False

# %%
td.go = True
td.run()

# %%
td.json_writer.path
# Out:
# '2020_11_30_00_38_04_software_test.jsontxt'

# %%
with open(td.json_writer.path, 'r') as f:
    for n in range(12):
        print(f.readline())
# Out:
# {"description": "dummy_data", "sample_n": 0, "degree": 0, "amplitude": 0.0, "std_time_ms": "2020-11-30 00:38:04.711936"}
#
# {"description": "dummy_data", "sample_n": 1, "degree": 1, "amplitude": 0.01745240643728351, "std_time_ms": "2020-11-30 00:38:04.712449"}
#
# {"description": "dummy_data", "sample_n": 2, "degree": 2, "amplitude": 0.03489949670250097, "std_time_ms": "2020-11-30 00:38:04.712726"}
#
# {"description": "dummy_data", "sample_n": 3, "degree": 3, "amplitude": 0.052335956242943835, "std_time_ms": "2020-11-30 00:38:04.712973"}
#
# {"description": "dummy_data", "sample_n": 4, "degree": 4, "amplitude": 0.0697564737441253, "std_time_ms": "2020-11-30 00:38:04.713223"}
#
# {"description": "dummy_data", "sample_n": 5, "degree": 5, "amplitude": 0.08715574274765817, "std_time_ms": "2020-11-30 00:38:04.713479"}
#
# {"description": "dummy_data", "sample_n": 6, "degree": 6, "amplitude": 0.10452846326765347, "std_time_ms": "2020-11-30 00:38:04.713729"}
#
# {"description": "dummy_data", "sample_n": 7, "degree": 7, "amplitude": 0.12186934340514748, "std_time_ms": "2020-11-30 00:38:04.713968"}
#
# {"description": "dummy_data", "sample_n": 8, "degree": 8, "amplitude": 0.13917310096006544, "std_time_ms": "2020-11-30 00:38:04.714200"}
#
# {"description": "dummy_data", "sample_n": 9, "degree": 9, "amplitude": 0.15643446504023087, "std_time_ms": "2020-11-30 00:38:04.714476", "encoding": "utf-8", "format": "text/json", "standard": "RFC 8259", "line_terminator": "\n", "quote_char": "\"", "double_quote": true, "escape_char": "\\", "null_sequence": "NA", "comment": "#", "metadata": {"name": "software_test", "urls": "www.example.com", "manufacturer": "Nikola Tesla Company", "state": "Test run() method", "header": ["description", "sample_n", "degree", "amplitude"], "dtype": ["str", "int", "float", "float"], "units": [null, "count", "degrees", "real numbers"], "accuracy": [null, 1, 0.2, 0.2], "precision": [null, 1, 0.1, 0.1], "bus_n": 1, "bus_addr": 0, "description": "dummy_data"}, "path": "2020_11_30_00_38_04_software_test.jsontxt", "time_format": "std_time_ms", "strfmtime": "%Y-%m-%d %H:%M:%S.%f", "metadata_interval": 10}
#
# {"description": "dummy_data", "sample_n": 10, "degree": 10, "amplitude": 0.17364817766693033, "std_time_ms": "2020-11-30 00:38:04.715065"}
#
# {"description": "dummy_data", "sample_n": 11, "degree": 11, "amplitude": 0.1908089953765448, "std_time_ms": "2020-11-30 00:38:04.715332"}

# %%
td.writer_output = 'csv'

# %%
td.go = True
td.run()

# %%
td.csv_writer.path
# Out:
# '2020_11_30_00_38_08_software_test.csv'

# %%
m, df = parser.csv_resource(td.csv_writer.path)

# %%
m
# Out:
# {'case_sensitive_header': False,
#  'comment': '#',
#  'delimiter': ',',
#  'double_quote': True,
#  'encoding': 'utf-8',
#  'escape_char': '\\',
#  'format': 'text/csv',
#  'line_terminator': '\n',
#  'metadata': {'accuracy': [None, 1, 0.2, 0.2],
#   'bus_addr': 0,
#   'bus_n': 1,
#   'description': 'dummy_data',
#   'dtype': ['str', 'int', 'float', 'float'],
#   'header': ['description', 'sample_n', 'degree', 'amplitude'],
#   'manufacturer': 'Nikola Tesla Company',
#   'name': 'software_test',
#   'precision': [None, 1, 0.1, 0.1],
#   'state': 'Test run() method',
#   'units': [None, 'count', 'degrees', 'real numbers'],
#   'urls': 'www.example.com'},
#  'null_sequence': 'NA',
#  'path': '2020_11_30_00_38_08_software_test.csv',
#  'quote_char': '"',
#  'skip_initial_space': True,
#  'skip_lines': 1,
#  'standard': 'Follow RFC 4180',
#  'strfmtime': '%Y-%m-%d %H:%M:%S.%f',
#  'time_format': 'std_time_ms'}

# %%
df
# Out:
#                     std_time_ms description  sample_n  degree  amplitude  \
# 0    2020-11-30 00:38:08.224783  dummy_data         0       0   0.000000
# 1    2020-11-30 00:38:08.225302  dummy_data         1       1   0.017452
# 2    2020-11-30 00:38:08.225776  dummy_data         2       2   0.034899
# 3    2020-11-30 00:38:08.226236  dummy_data         3       3   0.052336
# 4    2020-11-30 00:38:08.226739  dummy_data         4       4   0.069756
# ..                          ...         ...       ...     ...        ...
# 995  2020-11-30 00:38:08.469975  dummy_data       995     275  -0.996195
# 996  2020-11-30 00:38:08.470151  dummy_data       996     276  -0.994522
# 997  2020-11-30 00:38:08.470325  dummy_data       997     277  -0.992546
# 998  2020-11-30 00:38:08.470499  dummy_data       998     278  -0.990268
# 999  2020-11-30 00:38:08.470672  dummy_data       999     279  -0.987688
#
#                  datetime64_ns
# 0   2020-11-30 00:38:08.224783
# 1   2020-11-30 00:38:08.225302
# 2   2020-11-30 00:38:08.225776
# 3   2020-11-30 00:38:08.226236
# 4   2020-11-30 00:38:08.226739
# ..                         ...
# 995 2020-11-30 00:38:08.469975
# 996 2020-11-30 00:38:08.470151
# 997 2020-11-30 00:38:08.470325
# 998 2020-11-30 00:38:08.470499
# 999 2020-11-30 00:38:08.470672
#
# [1000 rows x 6 columns]

# %%
df[["std_time_ms", "degree", "amplitude"]].plot(x='std_time_ms',
                                                secondary_y="amplitude",
                                                figsize=(10,8), rot=45);

# %%
df.loc[0:359, ["degree", "amplitude"]].plot(x='degree', figsize=(10,8));

# %%
df.head()
# Out:
#                   std_time_ms description  sample_n  degree  amplitude  \
# 0  2020-11-30 00:38:08.224783  dummy_data         0       0   0.000000
# 1  2020-11-30 00:38:08.225302  dummy_data         1       1   0.017452
# 2  2020-11-30 00:38:08.225776  dummy_data         2       2   0.034899
# 3  2020-11-30 00:38:08.226236  dummy_data         3       3   0.052336
# 4  2020-11-30 00:38:08.226739  dummy_data         4       4   0.069756
#
#                datetime64_ns
# 0 2020-11-30 00:38:08.224783
# 1 2020-11-30 00:38:08.225302
# 2 2020-11-30 00:38:08.225776
# 3 2020-11-30 00:38:08.226236
# 4 2020-11-30 00:38:08.226739

# %%
df.tail()
# Out:
#                     std_time_ms description  sample_n  degree  amplitude  \
# 995  2020-11-30 00:38:08.469975  dummy_data       995     275  -0.996195
# 996  2020-11-30 00:38:08.470151  dummy_data       996     276  -0.994522
# 997  2020-11-30 00:38:08.470325  dummy_data       997     277  -0.992546
# 998  2020-11-30 00:38:08.470499  dummy_data       998     278  -0.990268
# 999  2020-11-30 00:38:08.470672  dummy_data       999     279  -0.987688
#
#                  datetime64_ns
# 995 2020-11-30 00:38:08.469975
# 996 2020-11-30 00:38:08.470151
# 997 2020-11-30 00:38:08.470325
# 998 2020-11-30 00:38:08.470499
# 999 2020-11-30 00:38:08.470672
